# %%
from cicada.encoder import FixedFieldEncoder

# %%
e = FixedFieldEncoder()
e
# Out:
# cicada.encoder.fixedfield.FixedFieldEncoder(field=cicada.math.field.Field(modulus=18446744073709551557), precision=16)

# %%
e.encode(3)
# Out:
# FixedFieldArray(196608, dtype=object)
