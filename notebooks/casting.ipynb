# %%
import logging
logging.basicConfig(level=logging.DEBUG)

import numpy

from cicada.math import Field, FieldArray
from cicada.encoder import FixedFieldArray, FixedFieldEncoder

# %%
a = FixedFieldArray([1, 2, 3, 4], modulus=251, precision=4)

# %%
a, a.modulus, a.precision
# Out:
# (FixedFieldArray([1, 2, 3, 4], dtype=object), 251, 4)

# %%
a[2:], a[2:].modulus, a[2:].precision
# Out:
# (FixedFieldArray([3, 4], dtype=object), 251, 4)

# %%
a.reshape((2, 2)), a.reshape((2, 2)).modulus, a.reshape((2, 2)).precision
# Out:
# (FixedFieldArray([[1, 2],
#                   [3, 4]], dtype=object),
#  251,
#  4)

# %%
b = FieldArray([1, 2, 3], modulus=251).view(FixedFieldArray)

# %%
b, b.modulus, b.precision
# Out:
# (FixedFieldArray([1, 2, 3], dtype=object), 251, None)
